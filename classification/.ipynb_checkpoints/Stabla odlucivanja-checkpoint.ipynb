# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier

plt.style.use('ggplot')

# %%
adresa = r'..\dataset\podaci_za_klasifikaciju\SMOTE'

# %%
def pripremi_podatke(adresa):
    X_train = pd.read_csv(f'{adresa}\X_resampled.csv')
    y_train = pd.read_csv(f'{adresa}\y_resampled.csv')
    X_test = pd.read_csv(f'{adresa}\X_test.csv')
    y_test = pd.read_csv(f'{adresa}\y_test.csv')
    return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = pripremi_podatke(adresa)
feature_names = X_train.columns

# %%
X_train
# Out:
#       Number_seasons  Games_played   At_bats      Runs      Hits   Doubles
# 0          -0.803653     -0.233679 -0.033919 -0.445957  0.050408 -0.428081  \
# 1           3.312272      4.316313  4.573471  4.132759  4.680752  4.674348
# 2          -0.803653     -0.096211  0.146113  0.100474 -0.031999 -0.144135
# 3          -0.803653     -0.067169  0.083222  0.240447  0.112602  0.518406
# 4          -1.120262     -0.611232 -0.574496 -1.021997 -0.747230 -0.686214
# ...              ...           ...       ...       ...       ...       ...
# 2728        1.423127      1.558610  1.810209  2.781197  1.571996  0.898010
# 2729        1.996076      2.007746  2.204834  2.292632  2.632997  2.432945
# 2730        1.030735      1.188522  1.354469  1.599356  1.651038  2.014016
# 2731        0.420766      0.892489  0.938757  0.488880  0.750930  0.621181
# 2732        1.232925      1.199497  1.399042  1.778690  1.836459  2.119274
#
#        Triples  Home_runs      RBIs     Walks  ...  On_base_pct  Slugging_pct
# 0     0.186375  -0.631676 -0.231155 -0.866172  ...    -0.555748     -0.375186  \
# 1     2.097414   0.767998  2.092011  3.847272  ...     1.234305      0.387493
# 2     0.236012  -0.775760 -0.675001  0.042237  ...    -0.373709     -1.038384
# 3    -0.558186  -0.055340 -0.158117 -0.129161  ...     0.111729      0.221693
# 4    -0.806373  -0.045048 -0.545780 -0.931303  ...    -1.921043     -0.590725
# ...        ...        ...       ...       ...  ...          ...           ...
# 2728  3.322159  -0.322623  0.447331  1.799234  ...     0.549702     -0.217708
# 2729  3.309630  -0.501263  1.407640  0.845746  ...     1.131365      0.710686
# 2730  2.553620   1.003472  1.997338  0.771580  ...     1.196310      1.725164
# 2731  1.582809  -0.513194  0.672480 -0.090332  ...    -0.714190     -0.417762
# 2732  2.685683   0.333525  1.580661  0.465652  ...     1.352392      1.512239
#
#       Fielding_ave  Catcher  Designated_hitter  First_base  Outfield
# 0         1.054496      0.0                0.0    1.000000  0.000000  \
# 1         0.974323      0.0                0.0    0.000000  1.000000
# 2        -1.310611      0.0                0.0    0.000000  0.000000
# 3         0.733803      0.0                0.0    0.000000  1.000000
# 4         0.613544      1.0                0.0    0.000000  0.000000
# ...            ...      ...                ...         ...       ...
# 2728     -0.857837      0.0                0.0    0.000000  0.000000
# 2729     -0.045878      0.0                0.0    0.000000  1.000000
# 2730      0.599483      0.0                0.0    0.603077  0.396923
# 2731     -1.198146      0.0                0.0    0.000000  0.000000
# 2732      0.371933      0.0                0.0    0.000000  1.000000
#
#       Second_base  Shortstop  Third_base
# 0             0.0   0.000000    0.000000
# 1             0.0   0.000000    0.000000
# 2             0.0   0.000000    1.000000
# 3             0.0   0.000000    0.000000
# 4             0.0   0.000000    0.000000
# ...           ...        ...         ...
# 2728          1.0   0.000000    0.000000
# 2729          0.0   0.000000    0.000000
# 2730          0.0   0.000000    0.000000
# 2731          0.0   0.867284    0.132716
# 2732          0.0   0.000000    0.000000
#
# [2733 rows x 22 columns]

# %%
y_train
# Out:
#       Hall_of_Fame
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 2728             2
# 2729             2
# 2730             2
# 2731             2
# 2732             2
#
# [2733 rows x 1 columns]

# %%
# !pip install termcolor
# !pip install imblearn
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from termcolor import colored

def report_imbalanced(model, x, y, text = "training"):
    y_pred = model.predict(x)
    
    print(colored("Classification report for model {} on {} data".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(classification_report_imbalanced(y, y_pred, zero_division=True))
    print("---------------------------------------------------------------------------------")
    
    print(colored("Confusion matrix for model {} on {} data ".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=['0', '1', '2'], index=['0', '1', '2']))
    print("---------------------------------------------------------------------------------")

# %%
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split, cross_val_score, learning_curve
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, classification_report, roc_curve, auc
     
def auc_curve_plot(X_train, X_test, y_train, y_test, model):
    classifier_ovr = OneVsRestClassifier(model)
    y_train_bin = label_binarize(y_train, classes=np.unique(y_train))
    y_test_bin = label_binarize(y_test, classes=np.unique(y_test))
    classifier_ovr.fit(X_train, y_train_bin)
    y_scores = classifier_ovr.predict_proba(X_test)

    fpr = {}
    tpr = {}
    roc_auc = {}

    for class_label in range(3):
        fpr[class_label], tpr[class_label], _ = roc_curve(y_test_bin[:, class_label], y_scores[:, class_label])
        roc_auc[class_label] = auc(fpr[class_label], tpr[class_label])

    plt.figure(figsize=(5, 5))
    colors = ['red', 'blue', 'green']
    classes = ['0 vs ostale', '1 vs ostale', '2 vs ostale']
    for class_label, color, class_name in zip(range(3), colors, classes):
        plt.plot(fpr[class_label], tpr[class_label], color=color, lw=2, label=f'{class_name} (AUC = {roc_auc[class_label]:.2f})')

    plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('One-vs-Rest AUC Curve')
    plt.legend(loc='lower right')

    plt.show()

# %%
def train_and_evaluate_model(X_train, Y_train, X_test, Y_test, model):
    model.fit(X_train, Y_train.values.ravel())
    report_imbalanced(model, X_train, Y_train, "training")
    report_imbalanced(model, X_test, Y_test, "test")
    auc_curve_plot(X_train, X_test, Y_train, Y_test, model)
    return model

# %% [markdown]
# ## SMOTE + Algoritmi stabala odlučivanja

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(k_neighbors=10, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dtc = DecisionTreeClassifier()
model_DTCSmote = train_and_evaluate_model(X_train, y_train, X_test, y_test, dtc)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00       911
#           1       1.00      1.00      1.00      1.00      1.00      1.00       911
#           2       1.00      1.00      1.00      1.00      1.00      1.00       911
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      2733
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  911    0    0
# 1    0  911    0
# 2    0    0  911
# ---------------------------------------------------------------------------------
# Classification report for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.94      0.81      0.96      0.87      0.77       304
#           1       0.41      0.64      0.96      0.50      0.79      0.60        14
#           2       0.36      0.47      0.96      0.41      0.67      0.43        17
#
# avg / total       0.92      0.90      0.82      0.91      0.86      0.74       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  285  8  11
# 1    2  9   3
# 2    4  5   8
# ---------------------------------------------------------------------------------

# %%
plot_tree(model_DTCSmote, feature_names=feature_names, class_names=['0', '1', '2'], filled=True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

params =  {
    'criterion': ['gini', 'entropy'],
    'max_depth': [x for x in range(3, 10)],
    'max_features': [x for x in range(3, 10)]
}

estimator = GridSearchCV(DecisionTreeClassifier(), param_grid=params, cv=3)

# %%
model_GSCVsmote = train_and_evaluate_model(X_train, y_train, X_test, y_test, estimator)
# Out:
# Classification report for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.92      1.00      0.96      0.96      0.91       911
#           1       0.99      1.00      1.00      1.00      1.00      1.00       911
#           2       0.93      0.99      0.96      0.96      0.98      0.96       911
#
# avg / total       0.97      0.97      0.99      0.97      0.98      0.96      2733
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  839    6   66
# 1    0  911    0
# 2    2    3  906
# ---------------------------------------------------------------------------------
# Classification report for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.89      0.81      0.93      0.85      0.72       304
#           1       0.39      0.50      0.97      0.44      0.69      0.46        14
#           2       0.29      0.71      0.91      0.41      0.80      0.63        17
#
# avg / total       0.92      0.86      0.82      0.88      0.84      0.71       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  270  8  26
# 1    4  7   3
# 2    2  3  12
# ---------------------------------------------------------------------------------

# %%
estimator.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 9, 'max_features': 7}

# %%
estimator.best_score_
# Out:
# 0.9275521405049396

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=2)

# %%
model_randomForestSmote = train_and_evaluate_model(X_train, y_train, X_test, y_test, random_forest)
# Out:
# Classification report for model RandomForestClassifier on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.95      0.99      0.97      0.97      0.98      0.97       911
#           1       0.97      0.99      0.99      0.98      0.99      0.98       911
#           2       0.99      0.93      1.00      0.96      0.96      0.92       911
#
# avg / total       0.97      0.97      0.99      0.97      0.98      0.95      2733
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  902    2    7
# 1    6  904    1
# 2   43   22  846
# ---------------------------------------------------------------------------------
# Classification report for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.97      0.95      0.68      0.96      0.80      0.66       304
#           1       0.37      0.50      0.96      0.42      0.69      0.46        14
#           2       0.19      0.18      0.96      0.18      0.41      0.16        17
#
# avg / total       0.90      0.90      0.70      0.90      0.78      0.63       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  290  4  10
# 1    4  7   3
# 2    6  8   3
# ---------------------------------------------------------------------------------

# %%
paramsForest = { 
    'max_depth' : [x for x in range(3, 14)],
    'max_features': [x for x in range(3, 10)],
    'criterion' :['gini', 'entropy']
}

# %%
estimatorforest = GridSearchCV(RandomForestClassifier(n_estimators=2), param_grid=paramsForest, cv=3)

# %%
model_randomFGSCVSmote = train_and_evaluate_model(X_train, y_train, X_test, y_test, estimatorforest)
# Out:
# Classification report for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.97      0.98      0.99      0.98      0.98      0.97       911
#           1       0.98      1.00      0.99      0.99      1.00      0.99       911
#           2       0.98      0.95      0.99      0.97      0.97      0.94       911
#
# avg / total       0.98      0.98      0.99      0.98      0.98      0.97      2733
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  893    2   16
# 1    0  911    0
# 2   25   16  870
# ---------------------------------------------------------------------------------
# Classification report for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.96      0.95      0.65      0.96      0.78      0.63       304
#           1       0.44      0.57      0.97      0.50      0.74      0.53        14
#           2       0.24      0.24      0.96      0.24      0.48      0.21        17
#
# avg / total       0.90      0.90      0.67      0.90      0.77      0.61       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  289  4  11
# 1    4  8   2
# 2    7  6   4
# ---------------------------------------------------------------------------------

# %%
estimatorforest.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 13, 'max_features': 8}

# %%
estimatorforest.best_score_
# Out:
# 0.924259055982437

# %%
def feature_importance(model):
    pd.Series(model.feature_importances_, index=feature_names).sort_values(ascending=False).plot.barh()
    plt.title("Feature importance")
    plt.show()

# %%
feature_importance(model_randomFGSCVSmote.best_estimator_)

# %%
feature_importance(model_GSCVsmote.best_estimator_)

# %% [markdown]
# ## SMOTENN + Algoritmi stabala odlučivanja

# %%
adresa = r'..\dataset\podaci_za_klasifikaciju\SMOTENN'

# %%
X_train, X_test, y_train, y_test = pripremi_podatke(adresa)
feature_names = X_train.columns

# %%
X_train
# Out:
#       Number_seasons  Games_played   At_bats      Runs      Hits   Doubles
# 0          -0.803653     -0.233679 -0.033919 -0.445957  0.050408 -0.428081  \
# 1          -0.803653     -0.096211  0.146113  0.100474 -0.031999 -0.144135
# 2          -0.803653     -0.067169  0.083222  0.240447  0.112602  0.518406
# 3          -1.120262     -0.611232 -0.574496 -1.021997 -0.747230 -0.686214
# 4          -0.487043     -0.698359 -0.729564 -0.537477 -0.675707 -0.514126
# ...              ...           ...       ...       ...       ...       ...
# 2579        2.962810      1.920201  1.940803  1.306941  1.729783  1.728384
# 2580       -0.180946      0.289222  0.516235  0.878136  0.793292  0.573142
# 2581        1.754103      0.944819  1.456467  2.217041  1.689180  1.842693
# 2582        1.286945      0.608625  0.390922  0.271837  0.435528  0.619780
# 2583        1.687205      0.742149  1.117679  2.439290  1.668532  2.191783
#
#        Triples  Home_runs      RBIs     Walks  ...  On_base_pct  Slugging_pct
# 0     0.186375  -0.631676 -0.231155 -0.866172  ...    -0.555748     -0.375186  \
# 1     0.236012  -0.775760 -0.675001  0.042237  ...    -0.373709     -1.038384
# 2    -0.558186  -0.055340 -0.158117 -0.129161  ...     0.111729      0.221693
# 3    -0.806373  -0.045048 -0.545780 -0.931303  ...    -1.921043     -0.590725
# 4    -0.558186  -0.683135 -0.790176 -0.519948  ...     0.020710     -0.507825
# ...        ...        ...       ...       ...  ...          ...           ...
# 2579  1.730327  -0.348331  1.207078  0.930403  ...    -0.086864     -0.289497
# 2580  2.808916  -0.381258  0.512940  0.533888  ...     1.606443      0.993730
# 2581  2.083415  -0.345491  1.332285  0.232719  ...     0.581132      0.550330
# 2582  0.198670  -0.623189  0.308832  1.157558  ...     1.457327     -0.171175
# 2583  3.926950   0.255953  2.051139  1.432275  ...     2.525249      2.138675
#
#       Fielding_ave   Catcher  Designated_hitter  First_base  Outfield
# 0         1.054496  0.000000                0.0    1.000000  0.000000  \
# 1        -1.310611  0.000000                0.0    0.000000  0.000000
# 2         0.733803  0.000000                0.0    0.000000  1.000000
# 3         0.613544  1.000000                0.0    0.000000  0.000000
# 4         0.653630  0.000000                0.0    0.000000  1.000000
# ...            ...       ...                ...         ...       ...
# 2579     -0.517771  0.000000                0.0    0.000000  0.000000
# 2580     -0.753549  0.000000                0.0    0.000000  1.000000
# 2581     -2.621430  0.000000                0.0    0.000000  0.921422
# 2582      0.741451  0.603077                0.0    0.396923  0.000000
# 2583      0.209832  0.000000                0.0    1.000000  0.000000
#
#       Second_base  Shortstop  Third_base
# 0        0.000000   0.000000         0.0
# 1        0.000000   0.000000         1.0
# 2        0.000000   0.000000         0.0
# 3        0.000000   0.000000         0.0
# 4        0.000000   0.000000         0.0
# ...           ...        ...         ...
# 2579     0.350627   0.649373         0.0
# 2580     0.000000   0.000000         0.0
# 2581     0.000000   0.078578         0.0
# 2582     0.000000   0.000000         0.0
# 2583     0.000000   0.000000         0.0
#
# [2584 rows x 22 columns]

# %%
y_train
# Out:
#       Hall_of_Fame
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 2579             2
# 2580             2
# 2581             2
# 2582             2
# 2583             2
#
# [2584 rows x 1 columns]

# %%
dtc = DecisionTreeClassifier()
model_DTCSmotenn = train_and_evaluate_model(X_train, y_train, X_test, y_test, dtc)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00       769
#           1       1.00      1.00      1.00      1.00      1.00      1.00       910
#           2       1.00      1.00      1.00      1.00      1.00      1.00       905
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      2584
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  769    0    0
# 1    0  910    0
# 2    0    0  905
# ---------------------------------------------------------------------------------
# Classification report for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.86      0.84      0.92      0.85      0.72       304
#           1       0.41      0.64      0.96      0.50      0.79      0.60        14
#           2       0.13      0.35      0.87      0.19      0.55      0.29        17
#
# avg / total       0.91      0.82      0.85      0.86      0.83      0.69       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  261  5  38
# 1    2  9   3
# 2    3  8   6
# ---------------------------------------------------------------------------------

# %%
plot_tree(model_DTCSmote, feature_names=feature_names, class_names=['0', '1', '2'], filled=True)
plt.show()

# %%
estimator = GridSearchCV(DecisionTreeClassifier(), param_grid=params, cv=3)

# %%
model_GSCVsmotenn = train_and_evaluate_model(X_train, y_train, X_test, y_test, estimator)
# Out:
# Classification report for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      0.97      1.00      0.99      0.99      0.97       769
#           1       0.98      0.99      0.99      0.98      0.99      0.98       910
#           2       0.97      0.98      0.98      0.97      0.98      0.96       905
#
# avg / total       0.98      0.98      0.99      0.98      0.99      0.97      2584
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  748    2   19
# 1    0  901    9
# 2    0   19  886
# ---------------------------------------------------------------------------------
# Classification report for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.99      0.82      0.90      0.90      0.86      0.73       304
#           1       0.41      0.64      0.96      0.50      0.79      0.60        14
#           2       0.18      0.65      0.84      0.28      0.74      0.53        17
#
# avg / total       0.92      0.80      0.90      0.85      0.85      0.72       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  249  9  46
# 1    1  9   4
# 2    2  4  11
# ---------------------------------------------------------------------------------

# %%
estimator.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 9, 'max_features': 9}

# %%
estimator.best_score_
# Out:
# 0.9663375470347345

# %%
random_forest = RandomForestClassifier(n_estimators=2)

# %%
model_randomForestSmotenn = train_and_evaluate_model(X_train, y_train, X_test, y_test, random_forest)
# Out:
# Classification report for model RandomForestClassifier on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.97      0.99      0.99      0.98      0.99      0.98       769
#           1       0.98      0.99      0.99      0.99      0.99      0.98       910
#           2       1.00      0.97      1.00      0.98      0.98      0.96       905
#
# avg / total       0.98      0.98      0.99      0.98      0.99      0.98      2584
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  765    2    2
# 1    8  901    1
# 2   15   14  876
# ---------------------------------------------------------------------------------
# Classification report for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.91      0.81      0.94      0.86      0.74       304
#           1       0.48      0.79      0.96      0.59      0.87      0.74        14
#           2       0.24      0.41      0.93      0.30      0.62      0.36        17
#
# avg / total       0.92      0.88      0.82      0.90      0.85      0.72       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#      0   1   2
# 0  277   7  20
# 1    1  11   2
# 2    5   5   7
# ---------------------------------------------------------------------------------

# %%
estimatorforest = GridSearchCV(RandomForestClassifier(), param_grid=paramsForest, cv=3)

# %%
model_randomFGSCVSmotenn = train_and_evaluate_model(X_train, y_train, X_test, y_test, estimatorforest)
# Out:
# Classification report for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       1.00      1.00      1.00      1.00      1.00      1.00       769
#           1       1.00      1.00      1.00      1.00      1.00      1.00       910
#           2       1.00      1.00      1.00      1.00      1.00      1.00       905
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      2584
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on training data
# ---------------------------------------------------------------------------------
#      0    1    2
# 0  769    0    0
# 1    0  910    0
# 2    0    0  905
# ---------------------------------------------------------------------------------
# Classification report for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.99      0.88      0.90      0.93      0.89      0.79       304
#           1       0.43      0.64      0.96      0.51      0.79      0.60        14
#           2       0.23      0.59      0.89      0.33      0.72      0.51        17
#
# avg / total       0.93      0.85      0.91      0.88      0.88      0.77       335
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model GridSearchCV on test data
# ---------------------------------------------------------------------------------
#      0  1   2
# 0  267  7  30
# 1    1  9   4
# 2    2  5  10
# ---------------------------------------------------------------------------------

# %%
estimatorforest.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 12, 'max_features': 9}

# %%
estimatorforest.best_score_
# Out:
# 0.9903258230460992

# %%
feature_importance(model_randomFGSCVSmotenn.best_estimator_)

# %%
feature_importance(model_GSCVsmotenn.best_estimator_)

# %%
import pickle

models = [model_DTCSmote, model_GSCVsmote, model_randomForestSmote, model_randomFGSCVSmote, 
          model_DTCSmotenn, model_GSCVsmotenn, model_randomForestSmotenn, model_randomFGSCVSmotenn]

model_names = ["model_DTC_Smote", "model_GSCV_smote", "model_randomForest_Smote", "model_randomFrst_GSCV_Smote", 
          "model_DTCS_motenn", "model_GSCV_smotenn", "model_randomForest_Smotenn", "model_randomForest_GSCV_Smotenn"]


for model, modelname in zip(models, model_names):
    with open(f'Sačuvani modeli za stabla odlučivanja/{modelname}.pkl', 'wb') as file:  
        pickle.dump(model, file)
